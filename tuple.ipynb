# %%
# empty tuple
l=()
print(l)
print(type(l))
# single value tuple
l1=(1,) 
print(l1)
print(type(l1))
# tuple definition
#collection of elements denoted by (paranthesis) with coma 
l2=(12,"hello",13,14,14.5,15) #heterogenous 
print(l2)
print(type(l2))
print(l2[0])  #indexed
print(l2)     #ordered
for i in l2:
    print(i)
l[0]=1000  #immutable
# Out:
# ()
# <class 'tuple'>
# (1,)
# <class 'tuple'>
# (12, 'hello', 13, 14, 14.5, 15)
# <class 'tuple'>
# 12
# (12, 'hello', 13, 14, 14.5, 15)
# 12
# hello
# 13
# 14
# 14.5
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      16 for i in l2:
#      17     print(i)
# ---> 18 l[0]=1000
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(10,20,30,100,10.5)
max_value=t[0]
min_value=t[0]
for i in t:
    if i>max_value:
        max_value=i
print(max_value)
for i in t:
    if i<min_value:
        min_value=i
print(min_value)
# Out:
# 100
# 10

# %%
t=(10,20,30,"hello",10.5)
print(len(t))
count=0
for i in t:
    count=count+1
print(count)
# Out:
# 5
# 5

# %%
t=(10,20,30,100,10.5)
t1=(sorted(t))
t2=()
for i in t1[::-1]:
    t2=t2+(i,)
print(t2)
# Out:
# (100, 30, 20, 10.5, 10)

# %%
t=(10,20,30,100,10.5)
t1=sorted(t,reverse=True)
print(t1)
# Out:
# [100, 30, 20, 10.5, 10]
